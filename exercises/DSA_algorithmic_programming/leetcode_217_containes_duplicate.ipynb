# %% [markdown]
# # 217. Contains Duplicate :
# Problem : https://leetcode.com/problems/contains-duplicate/description/
#
# Solution : https://www.youtube.com/watch?v=3OamzN90kPg&t=387s
#
# Best solution from Leetcode: https://leetcode.com/problems/contains-duplicate/solutions/3672475/4-methods-c-java-python-beginner-friendl-zozw
#
# Given an integer array nums, return true if any value appears at least twice in the array, and return false if every element is distinct.
#
# Example 1:
#
# Input: nums = [1,2,3,1]
#
# Output: true
#
# Explanation:
#
# The element 1 occurs at the indices 0 and 3.
#
# Example 2:
#
# Input: nums = [1,2,3,4]
#
# Output: false
#
# Explanation:
#
# All elements are distinct.
#
# Example 3:
#
# Input: nums = [1,1,1,3,3,4,3,2,4,2]
#
# Output: true
#
# Constraints:
#
# 1 <= nums.length <= 105
# -109 <= nums[i] <= 109

# %%
class Solution:
    def containsDuplicate(self, nums: List[int]) -> bool:
        nums_hashset = set()
        for num in nums:
            if num in nums_hashset:
                return True
            else:
                nums_hashset.add(num)
        return False

sol = Solution()
print(sol.containsDuplicate([1,3,2,4,1,3]))
# Out:
# True

# %% [markdown]
# **Refined solution**

# %%
class Solution:
    def containsDuplicate(self, nums: List[int]) -> bool:

        # Naming Convention nums_hashset is accurate but verbose. In industry, for a general set used to track visited items, we often use the variable name seen. It reads like a sentence: if num in seen

        seen = set()
        for num in nums:

        # Flatten the Logic (The "Guard Clause") In production code, we avoid unnecessary indentation. Since the if statement returns, you do not need the else.

            if num in seen:
                return True
            seen.add(num)
        return False

sol = Solution()
print(sol.containsDuplicate([1,3,2,4,1,3]))
# Out:
# True
