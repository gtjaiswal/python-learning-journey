# %% [markdown]
# # 242. Valid Anagram
#
# Problem: https://leetcode.com/problems/valid-anagram/description/
# Solution: https://www.youtube.com/watch?v=9UtInBqnCgA
#
# Given two strings s and t, return true if t is an anagram of s, and false otherwise.
#
# Example 1:
#
# Input: s = "anagram", t = "nagaram"
#
# Output: true
#
# Example 2:
#
# Input: s = "rat", t = "car"
#
# Output: false
#
# Constraints:
#
# 1 <= s.length, t.length <= 5 * 104
# s and t consist of lowercase English letters.
#
# Follow up: What if the inputs contain Unicode characters? How would you adapt your solution to such a case?

# %%
from collections import defaultdict, Counter


class Solution:
    def isAnagram(self, s: str  , t: str) -> bool:
        if len(t)==len(s):
            s_char_map=defaultdict(int)
            for s_char in s:
                    s_char_map[s_char]+=1
            for t_char in t:
                s_char_map[t_char] -=1
                if s_char_map[t_char]<0:
                    return False
            return True
        return False

sol = Solution()
s="ab"
t= "a"
sol.isAnagram(s,t)
# Out:
# False

# %%
class Solution:
    def isAnagram(self, s: str  , t: str) -> bool:
        if len(t)!=len(s):
            return False
        s_char_map = {}
        for s_char in s:
            s_char_map[s_char] = 1 + s_char_map.get(s_char,0)
        for t_char in t:
            s_char_map[t_char] = s_char_map.get(t_char,0) - 1
            if s_char_map[t_char]<0:
                return False
        return  True


sol = Solution()
s="anagram"
t= "naragam"
sol.isAnagram(s,t)
# Out:
# True

# %%
import collections
class Solution:
    def isAnagram(self, s: str  , t: str) -> bool:
        if len(t)!=len(s):
            return False
        s_char_counts = Counter(s)
        print(s_char_counts)
        t_char_counts=Counter(t)
        print(t_char_counts)
        return s_char_counts==t_char_counts


sol = Solution()
s="anagram"
t= "naragam"
sol.isAnagram(s,t)
# Out:
# Counter({'a': 3, 'n': 1, 'g': 1, 'r': 1, 'm': 1})
# Counter({'a': 3, 'n': 1, 'r': 1, 'g': 1, 'm': 1})
# True
