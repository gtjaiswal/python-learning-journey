# %% [markdown]
# # 1. Two Sum:
#
# Problem : https://leetcode.com/problems/two-sum/description/
#
# Solution : https://www.youtube.com/watch?v=KLlXCFG5TnA&list=PLot-Xpze53lfQmTEztbgdp8ALEoydvnRQ&index=2
#
# Best solution from Leetcode: https://leetcode.com/problems/contains-duplicate/solutions/3672475/4-methods-c-java-python-beginner-friendl-zozw
#
# Given an array of integers nums and an integer target, return indices of the two numbers such that they add up to target.
#
# You may assume that each input would have exactly one solution, and you may not use the same element twice.
#
# You can return the answer in any order.
#
#
# Example 1:
#
# Input: nums = [2,7,11,15], target = 9
# Output: [0,1]
# Explanation: Because nums[0] + nums[1] == 9, we return [0, 1].
# Example 2:
#
# Input: nums = [3,2,4], target = 6
# Output: [1,2]
# Example 3:
#
# Input: nums = [3,3], target = 6
# Output: [0,1]
#
#
# Constraints:
#
# 2 <= nums.length <= 104
# -109 <= nums[i] <= 109
# -109 <= target <= 109
# Only one valid answer exists.
#
#
# Follow-up: Can you come up with an algorithm that is less than O(n2) time complexity?

# %%
from typing import List


class Solution:
    def twoSum(self, nums: List[int], target: int) -> List[int]:
        seen = {}
        for index, num in enumerate(nums):
            compliment = target - num
            if compliment in seen:
                return [index, seen[compliment]]
            seen[num]=index
        return []

sol = Solution()
print(sol.twoSum([-1],6))
# Out:
# []

# %% [markdown]
# **Refined Solution**

# %%
from typing import List


class Solution:
    def twoSum(self, nums: List[int], target: int) -> List[int]:
        seen = {}
        for index, num in enumerate(nums):
# Precision in Naming
# Draft: compliment (means to give someone praise).
# Production: complement (means a thing that completes something else).
# It seems trivial, but in a code review at a top-tier firm, precise terminology signals attention to detail.
            complement = target - num
            if complement in seen:
# Return Order
# You returned [index, seen[complement]].
# While LeetCode accepts any order, logically the seen[complement] index appears earlier in the array than index. Returning [seen[complement], index] aligns better with the chronological flow of the array, though your version is technically correct.
                return [seen[complement],index]
            seen[num]=index
        return []

sol = Solution()
print(sol.twoSum([-1],6))
