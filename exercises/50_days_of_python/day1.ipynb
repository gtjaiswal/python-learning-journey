# %% [markdown]
# ## Day 1: Division and Square-root
# **Write a function called divide_or_square**
# - that takes one argument (a number),
# - returns the square root of the number if it is divisible by 5, returns its remainder if it is not divisible by 5. For example, if you
# pass 10 as an argument, then your function should return 3.16 as the square root

# %%
from math import sqrt

def divide_or_square(num:int):
    return(round(sqrt(num),2) if num%5==0 else num%5 )

print(divide_or_square(11.6))
print(divide_or_square(4))
# Out:
# 1.5999999999999996
# 4

# %% [markdown]
# ## Day 2: Strings to Integers
# **Write a function called convert_add**
# - that takes a list of strings as an argument
# - converts it to integers and sums the list. For example [‘1’, ‘3’, ‘5’] should be converted to [1, 3, 5] and summed to 9

# %%
def convert_add(num_list: list):
    total = 0
    for n in num_list:
        total += int(n)
    return total

# or using a generator expression
def convert_add_gen(num_list: list):
    return sum(int(x) for x in num_list)

# or using inline map
def convert_add_map(num_list: list):
    return sum(map(int, num_list))


print(convert_add(['1','3','5']))
print(convert_add_gen(['1','3','5']))
print(convert_add_map(['1','3','5']))
# Out:
# 9
