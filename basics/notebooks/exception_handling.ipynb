# %%
f = open("day1_task_word_frequency_input.txt")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 f = open("day1_task_word_frequency_input.txt")
#
# File ~/Learning/AI-ML/ai-ml-learning-journey/.venv/lib/python3.14/site-packages/IPython/core/interactiveshell.py:343, in _modified_open(file, *args, **kwargs)
#     336 if file in {0, 1, 2}:
#     337     raise ValueError(
#     338         f"IPython won't let you open fd={file} by default "
#     339         "as it is likely to crash IPython. If you know what you are doing, "
#     340         "you can use builtins' open."
#     341     )
# --> 343 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'day1_task_word_frequency_input.txt'

# %%
try:
    f = open("../data/day1_task_word_frequency_input.txt")
    # var = bad_var
except FileNotFoundError:
    print("Sorry couldnt find the file")
except Exception as exp:
    print("some other error : ",exp)
else:
    print(f.read())
finally:
    f.close()
# Out:
# Hello!! hello, HELLO?? World!!! 12hello £$h%ghello heelo

# %%
try:
    f = open("../data/day1_task_word_frequency_input.txt")
    if (f.name=='../data/day1_task_word_frequency_input.txt'):
        raise Exception("my exppppp")
except FileNotFoundError:
    print("Sorry couldnt find the file")
except Exception as exp:
    print("raised exception : ", exp)
else:
    print(f.read())
finally:
    print(f.read())
    f.close()
# Out:
# raised exception :  my exppppp
# Hello!! hello, HELLO?? World!!! 12hello £$h%ghello heelo
